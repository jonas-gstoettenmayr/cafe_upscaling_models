# %% [markdown]
# # Data showcasing

# %% [markdown]
# ## Raw data

# %%
import pandas as pd
import plotly.graph_objects as go

# %%
data = pd.read_csv("cafe_upscaling_models/data/raw_data/drinks.csv", parse_dates=["Date"]) # possibly chnage directory here

# %%
fig = go.Figure()

drinks = data.columns[1:]
colours = ['#9CB349', '#9f85bb', '#f0c03f', "#8a3d25", "#47231e", "#AD704D", "#8b541d", "#eab287", "#ed6313", "#7ba4d1"]

for i, drink in enumerate(drinks):
    fig.add_trace(go.Scatter(
        x=data["Date"],
        y=data[drink],
        mode='lines+markers',
        name=drink,
        line=dict(
            color=colours[i],
            dash='dashdot',
            width=2
        ),
        marker=dict(size=6)
    ))

fig.update_layout(
    title=dict(
        text="Daily Drink Counts",
        font=dict(size=28),
        x=0.5,
        y=0.96
    ),
    xaxis_title="Date",
    yaxis_title="Count",
    template="plotly_dark",
    legend=dict(
        title="Drink Type",
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    ),
    xaxis=dict(showgrid=True, gridcolor='dimgrey'),
    yaxis=dict(showgrid=True, gridcolor='dimgrey'),
    plot_bgcolor='#303438',
    paper_bgcolor='#303438'
)

fig.show()

# %% [markdown]
# ## Bubble tea problem

# %%
data_cut = data[(data["Date"] >= "2022-11-01") & (data["Date"] <= "2023-03-01")]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
        x=data_cut["Date"],
        y=data_cut["Bubble tea"],
        mode='lines+markers',
        name="Bubble tea",
        line=dict(
            color='#9f85bb',
            dash='dashdot',
            width=2
        ),
        marker=dict(size=6),
    ))

fig.add_trace(go.Scatter(
        x=data_cut["Date"],
        y=data_cut["Matcha"],
        mode='lines+markers',
        name="Bubble tea",
        line=dict(
            color='#9CB349',
            dash='dashdot',
            width=2
        ),
        marker=dict(size=6),
    ))

fig.update_layout(
    title=dict(
        text="The Bubble Tea Day",
        font=dict(size=28),
        x=0.5,
        y=0.96
    ),
    xaxis_title="Date",
    yaxis_title="Count",
    template="plotly_dark",
    legend=dict(
        title="Drink Type",
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    ),
    xaxis=dict(showgrid=True, gridcolor='dimgrey'),
    yaxis=dict(showgrid=True, gridcolor='dimgrey'),
    plot_bgcolor='#303438',
    paper_bgcolor='#303438',
    autosize = False,
    width=600, height=600
)

fig.show()

# %% [markdown]
# ## Data Preprocessed

# %%
def unlong(data):
    drinks = ["Matcha", "Bubble tea", "Tea", "Hot chocolate", "Espresso", "Latte macchiato", "Cappuccino", "Chai latte", "Pumpkin spice latte", "Iced coffee"]

    subset = data.loc[data["unique_id"] == drinks[0], ["ds"]]

    data2 = pd.DataFrame({"Date": subset["ds"].tolist()})

    for i in range(len(drinks)):
            
        subset = data.loc[data["unique_id"] == drinks[i], ["y"]]

        y = subset["y"].tolist()

        data2[f"{drinks[i]}"] = y

    return data2

# %%
data_prep = pd.read_parquet("cafe_upscaling_models/data/processed_data/df_outliers_capped.parquet") # possibly chnage directory here
data_prep2 = unlong(data_prep)

# %%
fig = go.Figure()

drinks = data_prep2.columns[1:]
colours = ['#9CB349', '#9f85bb', '#f0c03f', "#8a3d25", "#47231e", "#AD704D", "#8b541d", "#eab287", "#ed6313", "#7ba4d1"]

for i, drink in enumerate(drinks):
    fig.add_trace(go.Scatter(
        x=data_prep2["Date"],
        y=data_prep2[drink],
        mode='lines+markers',
        name=drink,
        line=dict(
            color=colours[i],
            dash='solid',
            width=1
        ),
        marker=dict(size=4)
    ))

fig.update_layout(
    title=dict(
        text="Daily Drink Counts",
        font=dict(size=28),
        x=0.5,
        y=0.96
    ),
    xaxis_title="Date",
    yaxis_title="Count",
    template="plotly_dark",
    legend=dict(
        title="Drink Type",
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    ),
    xaxis=dict(showgrid=True, gridcolor='dimgrey'),
    yaxis=dict(showgrid=True, gridcolor='dimgrey'),
    plot_bgcolor='#303438',
    paper_bgcolor='#303438',
    width=1200, height=600,
)

fig.show()

# %% [markdown]
# ### More recent

# %%
data_prep2 = data_prep2[data_prep2["Date"] >= "2024-01-01"]

fig = go.Figure()

drinks = data_prep2.columns[1:]
colours = ['#9CB349', '#9f85bb', '#f0c03f', "#8a3d25", "#47231e", "#AD704D", "#8b541d", "#eab287", "#ed6313", "#7ba4d1"]

for i, drink in enumerate(drinks):
    fig.add_trace(go.Scatter(
        x=data_prep2["Date"],
        y=data_prep2[drink],
        mode='lines+markers',
        name=drink,
        line=dict(
            color=colours[i],
            dash='solid',
            width=1
        ),
        marker=dict(size=4)
    ))

fig.update_layout(
    title=dict(
        text="Daily Drink Counts",
        font=dict(size=28),
        x=0.5,
        y=0.96
    ),
    xaxis_title="Date",
    yaxis_title="Count",
    template="plotly_dark",
    legend=dict(
        title="Drink Type",
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    ),
    xaxis=dict(showgrid=True, gridcolor='dimgrey'),
    yaxis=dict(showgrid=True, gridcolor='dimgrey'),
    plot_bgcolor='#303438',
    paper_bgcolor='#303438',
    width=1000, height=600,
    margin=dict(t=160)
)

fig.show()

# %% [markdown]
# ## Engineered reatures

# %%
features = pd.read_parquet("cafe_upscaling_models/data/processed_data/fourier+trend+holidays_test.parquet") # possibly chnage directory here

# %%
fourier_cols = [x for x in features.columns if (('sin' in x) or ('cos' in x)) and ('holiday' not in x)]
fourier_cols
# Out:
# ['sin1_7', 'sin2_7', 'sin3_7', 'cos1_7', 'cos2_7', 'cos3_7']

# %%
def plot_drink_features(df, drink):
    d = df[df["unique_id"] == drink].copy()

    colours = {"Matcha": '#9CB349', 
                "Bubble tea": '#9f85bb', 
                "Tea": '#f0c03f',
                "Hot chocolate": "#8a3d25", 
                "Espresso": "#47231e", 
                "Latte macchiato": "#AD704D", 
                "Cappuccino": "#8b541d", 
                "Chai latte": "#eab287", 
                "Pumpkin spice latte": "#ed6313",
                "Iced coffee": "#7ba4d1"}

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=d["ds"],
        y=d["y"],
        mode="lines+markers",
        name="Observed",
        line=dict(color=colours[drink], width=2),
        marker=dict(size=4)
    ))

    from sklearn.linear_model import LinearRegression

    model = LinearRegression()
    model.fit(df[fourier_cols], df['y'])

    df['fourier_combined'] = model.predict(df[fourier_cols])

    fig.add_trace(go.Scatter(
        x=d["ds"],
        y=df['fourier_combined'],
        name="Weekly Seasonality (Fourier)",
        line=dict(color="#5c76e1", width=2, dash="solid")
    ))

    holidays = d[d["is_holiday"]]

    for _, row in holidays.iterrows():
        fig.add_vline(
            x=row["ds"],
            line_width=3,
            line_dash="solid",
            line_color="#39b9ef",
            name = "Holiday",
            opacity=0.8
        )

    fig.update_layout(
        title=dict(
            text=f"{drink} + Engineered Features",
            font=dict(size=26),
            x=0.5
        ),
        template="plotly_dark",
        width=1100,
        height=650,
        margin=dict(t=100),
        plot_bgcolor="#303438",
        paper_bgcolor="#303438",
        xaxis=dict(title="Date", showgrid=True, gridcolor="dimgrey"),
        yaxis=dict(title="Count", showgrid=True, gridcolor='dimgrey'),
        legend=dict(
            orientation="h",
            yanchor="bottom",
            y=1.02,
            xanchor="center",
            x=0.5
        )
    )

    fig.show()

# %%
plot_drink_features(features, "Tea")

# %% [markdown]
# # Predictions

# %% [markdown]
# ## Comparing Best to Baseline and Truth

# %%
preds = pd.read_parquet("cafe_upscaling_models/data/predictions/test_predictions_long.parquet") # possibly chnage directory here
preds["unique_id"] = preds["unique_id"].apply(lambda x: x.replace('"', ''))
preds
# Out:
#                       model_name   unique_id         ds       y   preditions
# 0     Baseline (SeasonalNaive-7)  Bubble tea 2025-11-01  1148.0  1382.000000
# 1     Baseline (SeasonalNaive-7)  Bubble tea 2025-11-02  1095.0  1316.000000
# 2     Baseline (SeasonalNaive-7)  Bubble tea 2025-11-03  1097.0  1229.000000
# 3     Baseline (SeasonalNaive-7)  Bubble tea 2025-11-04  1089.0  1429.000000
# 4     Baseline (SeasonalNaive-7)  Bubble tea 2025-11-05  1218.0  1112.000000
# ...                          ...         ...        ...     ...          ...
# 1215              Best (AutoETS)         Tea 2025-12-27     NaN  1125.839810
# 1216              Best (AutoETS)         Tea 2025-12-28     NaN  1194.476400
# 1217              Best (AutoETS)         Tea 2025-12-29     NaN  1255.664828
# 1218              Best (AutoETS)         Tea 2025-12-30     NaN  1254.233791
# 1219              Best (AutoETS)         Tea 2025-12-31     NaN  1253.418165
#
# [1220 rows x 5 columns]

# %%
def unlong2(data):
    drinks = ["Matcha", "Bubble tea", "Tea", "Hot chocolate", "Espresso", "Latte macchiato", "Cappuccino", "Chai latte", "Pumpkin spice latte", "Iced coffee"]
    models = data['model_name'].unique().tolist()

    subset = data.loc[(data["unique_id"] == drinks[0]) & (data["model_name"] == models[0]), ["ds"]]

    data2 = pd.DataFrame({"Date": subset["ds"].tolist()})

    for i in range(len(drinks)):
            
        subset = data.loc[(data["unique_id"] == drinks[i]) & (data["model_name"] == models[0]), ["y", "preditions"]]

        #y = subset["y"].tolist()

        pred = subset["preditions"].tolist()

        #data2[f"True {drinks[i]}"] = y

        data2[f"PBase {drinks[i]}"] = pred

    for i in range(len(drinks)):
            
        subset = data.loc[(data["unique_id"] == drinks[i]) & (data["model_name"] == models[1]), ["y", "preditions"]]

        pred = subset["preditions"].tolist()

        data2[f"PBest {drinks[i]}"] = pred

    return data2

# %%
preds_ = unlong2(preds)
preds_
# Out:
#          Date  PBase Matcha  PBase Bubble tea  PBase Tea  PBase Hot chocolate  \
# 0  2025-11-01        4249.0            1382.0     1265.0                411.0
# 1  2025-11-02        4268.0            1316.0     1282.0                412.0
# 2  2025-11-03        3867.0            1229.0     1415.0                387.0
# 3  2025-11-04        3653.0            1429.0     1368.0                394.0
# 4  2025-11-05        4056.0            1112.0     1274.0                401.0
# ..        ...           ...               ...        ...                  ...
# 56 2025-12-27        4249.0            1382.0     1265.0                411.0
# 57 2025-12-28        4268.0            1316.0     1282.0                412.0
# 58 2025-12-29        3867.0            1229.0     1415.0                387.0
# 59 2025-12-30        3653.0            1429.0     1368.0                394.0
# 60 2025-12-31        4056.0            1112.0     1274.0                401.0
#
# ...

# %%
truth_cut = data_prep2[(data_prep2["Date"] >= "2025-11-01") & (data_prep2["Date"] <= "2025-12-31")]

# %%
truth_cut
# Out:
#             Date  Matcha  Bubble tea   Tea  Hot chocolate  Espresso  \
# 1400  2025-11-01    4018        1148  1076            386       736
# 1401  2025-11-02    4417        1095  1279            423       915
# 1402  2025-11-03    3897        1097  1275            402       878
# 1403  2025-11-04    3774        1089  1290            371       816
# 1404  2025-11-05    3803        1218  1182            353       830
# 1405  2025-11-06    3854        1062  1177            408       813
# 1406  2025-11-07    3878        1152  1266            472       848
# 1407  2025-11-08    4406        1296  1178            456       853
# 1408  2025-11-09    4683        1328  1269            501       808
# 1409  2025-11-10    3985        1078  1390            492       986
# 1410  2025-11-11    3777        1073  1266            552       833
# 1411  2025-11-12    3779        1023  1332            498       833
# 1412  2025-11-13    4223        1135  1296            472       791
# ...

# %%
def plot_drink(drink, df):

    fig = go.Figure()

    colours = {"Matcha": '#9CB349', 
                "Bubble tea": '#9f85bb', 
                "Tea": '#f0c03f',
                "Hot chocolate": "#8a3d25", 
                "Espresso": "#47231e", 
                "Latte macchiato": "#AD704D", 
                "Cappuccino": "#8b541d", 
                "Chai latte": "#eab287", 
                "Pumpkin spice latte": "#ed6313",
                "Iced coffee": "#7ba4d1"}

    
    fig.add_trace(go.Scatter(
        x=df["Date"],
        y=df[f"PBase {drink}"],
        mode='lines+markers',
        name='Baseline Prediction',
        line=dict(
            color="#408c5c",
            dash='solid',
            width=2
        ),
        marker=dict(size=4)
    ))

    fig.add_trace(go.Scatter(
        x=df["Date"],
        y=df[f"PBest {drink}"],
        mode='lines+markers',
        name='Best Prediction',
        line=dict(
            color="#6e6dc9",
            dash='solid',
            width=2
        ),
        marker=dict(size=4)
    ))

    fig.add_trace(go.Scatter(
        x=truth_cut["Date"],
        y=truth_cut[f"{drink}"],
        mode='lines+markers',
        name='Truth',
        line=dict(
            color=colours[f"{drink}"],
            dash='solid',
            width=2
        ),
        marker=dict(size=4)
    ))

    fig.update_layout(
        title=dict(
            text=f"{drink}",
            font=dict(size=28),
            x=0.5,
            y=0.96
        ),
        xaxis_title="Date",
        yaxis_title="Count",
        template="plotly_dark",
        xaxis=dict(showgrid=True, gridcolor='dimgrey'),
        yaxis=dict(showgrid=True, gridcolor='dimgrey'),
        plot_bgcolor='#303438',
        paper_bgcolor='#303438',
        width=1000, height=600,
        margin=dict(t=100)
    )

    fig.show()

# %% [markdown]
# ## All drinks separately

# %%
drinks = ["Matcha", "Bubble tea", "Tea", "Hot chocolate", "Espresso", "Latte macchiato", "Cappuccino", "Chai latte", "Pumpkin spice latte", "Iced coffee"]

for drink in drinks: plot_drink(drink, preds_)

# %% [markdown]
# ## Comparing Errors

# %%
def plot_daily_total_error(truth, preds):
    truth["Date"] = pd.to_datetime(truth["Date"])
    preds["Date"] = pd.to_datetime(preds["Date"])

    truth_nov = truth[
        (truth["Date"] >= "2025-11-01") &
        (truth["Date"] <= "2025-11-30")
    ].copy()

    preds_nov = preds[
        (preds["Date"] >= "2025-11-01") &
        (preds["Date"] <= "2025-11-30")
    ].copy()


    df = truth_nov.merge(preds_nov, on="Date", how="inner")

    drinks = truth.columns.drop("Date")

    base_errors = []
    best_errors = []

    for drink in drinks:
        base_errors.append(df[drink] - df[f"PBase {drink}"])
        best_errors.append(df[drink] - df[f"PBest {drink}"])

    df["total_error_base"] = pd.concat(base_errors, axis=1).sum(axis=1)
    df["total_error_best"] = pd.concat(best_errors, axis=1).sum(axis=1)


    fig = go.Figure()

    fig.add_trace(go.Bar(
        x=df["Date"],
        y=df["total_error_base"],
        name="Baseline (Truth - PBase)",
        marker_color="#f0c03f"
    ))

    fig.add_trace(go.Bar(
        x=df["Date"],
        y=df["total_error_best"],
        name="Best (Truth - PBest)",
        marker_color="#6a56f1"
    ))

    fig.add_hline(
        y=0,
        line_width=1,
        line_dash="dash",
        line_color="white",
        opacity=0.6
    )

    fig.update_layout(
        title=dict(
            text="Daily Total Error Across All Drinks (November)",
            font=dict(size=26),
            x=0.5
        ),
        template="plotly_dark",
        barmode="group",
        width=1100,
        height=600,
        margin=dict(t=100),
        plot_bgcolor="#303438",
        paper_bgcolor="#303438",
        xaxis=dict(
            title="Date",
            tickangle=-45,
            showgrid=True, gridcolor='dimgrey'
        ),
        yaxis=dict(title="Total Error (Truth - Prediction)", showgrid=True, gridcolor='dimgrey'),
        legend=dict(
            orientation="h",
            y=1.02,
            x=0.5,
            xanchor="center"
        )
    )

    fig.show()

# %%
plot_daily_total_error(truth_cut, preds_)
# Out:
# /var/folders/2y/jgnyhrhd0xl40br_pw__t8bm0000gn/T/ipykernel_50827/2742664601.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## January Prediction

# %%
preds2 = pd.read_parquet("cafe_upscaling_models/data/predictions/test_predictions_extended_long.parquet") # possibly chnage directory here
preds2["unique_id"] = preds2["unique_id"].apply(lambda x: x.replace('"', ''))
preds2
# Out:
#                       model_name   unique_id         ds       y   preditions
# 0     Baseline (SeasonalNaive-7)  Bubble tea 2025-11-01  1148.0  1382.000000
# 1     Baseline (SeasonalNaive-7)  Bubble tea 2025-11-02  1095.0  1316.000000
# 2     Baseline (SeasonalNaive-7)  Bubble tea 2025-11-03  1097.0  1229.000000
# 3     Baseline (SeasonalNaive-7)  Bubble tea 2025-11-04  1089.0  1429.000000
# 4     Baseline (SeasonalNaive-7)  Bubble tea 2025-11-05  1218.0  1112.000000
# ...                          ...         ...        ...     ...          ...
# 1835              Best (AutoETS)         Tea 2026-01-27     NaN  1254.233791
# 1836              Best (AutoETS)         Tea 2026-01-28     NaN  1253.418165
# 1837              Best (AutoETS)         Tea 2026-01-29     NaN  1237.329451
# 1838              Best (AutoETS)         Tea 2026-01-30     NaN  1170.729862
# 1839              Best (AutoETS)         Tea 2026-01-31     NaN  1125.839810
#
# [1840 rows x 5 columns]

# %%
def unlong3(data):
    drinks = ["Matcha", "Bubble tea", "Tea", "Hot chocolate", "Espresso", "Latte macchiato", "Cappuccino", "Chai latte", "Pumpkin spice latte", "Iced coffee"]
    models = data['model_name'].unique().tolist()

    data = data[(data["ds"] >= "2026-01-01") & (data["ds"] <= "2026-01-31")]

    subset = data.loc[(data["unique_id"] == drinks[0]) & (data["model_name"] == models[0]), ["ds"]]

    data2 = pd.DataFrame({"Date": subset["ds"].tolist()})

    for i in range(len(drinks)):
            
        subset = data.loc[(data["unique_id"] == drinks[i]) & (data["model_name"] == models[0]), ["preditions"]]

        pred = subset["preditions"].tolist()

        data2[f"PBase {drinks[i]}"] = pred

    for i in range(len(drinks)):
            
        subset = data.loc[(data["unique_id"] == drinks[i]) & (data["model_name"] == models[1]), ["preditions"]]

        pred = subset["preditions"].tolist()

        data2[f"PBest {drinks[i]}"] = pred

    return data2

# %%
preds_2 = unlong3(preds2)
preds_2
# Out:
#          Date  PBase Matcha  PBase Bubble tea  PBase Tea  PBase Hot chocolate  \
# 0  2026-01-01        3649.0            1196.0     1286.0                387.0
# 1  2026-01-02        3478.0            1085.0     1110.0                423.0
# 2  2026-01-03        4249.0            1382.0     1265.0                411.0
# 3  2026-01-04        4268.0            1316.0     1282.0                412.0
# 4  2026-01-05        3867.0            1229.0     1415.0                387.0
# 5  2026-01-06        3653.0            1429.0     1368.0                394.0
# 6  2026-01-07        4056.0            1112.0     1274.0                401.0
# 7  2026-01-08        3649.0            1196.0     1286.0                387.0
# 8  2026-01-09        3478.0            1085.0     1110.0                423.0
# 9  2026-01-10        4249.0            1382.0     1265.0                411.0
# 10 2026-01-11        4268.0            1316.0     1282.0                412.0
# ...

# %%
drinks = ["Matcha", "Bubble tea", "Tea", "Hot chocolate", "Espresso", "Latte macchiato", "Cappuccino", "Chai latte", "Pumpkin spice latte", "Iced coffee"]

for drink in drinks: plot_drink(drink, preds_2)
